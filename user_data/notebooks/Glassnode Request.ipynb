# %%
import pandas as pd
import requests
import json

from user_data.litmus.glassnode import download_data

import os
from pathlib import Path
os.chdir("/Users/mregan/Dev/litmus/")
print(Path.cwd())

# %load_ext autoreload
# %autoreload 2
# Out:
# /Users/mregan/Dev/litmus
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
gn = download_data.GlassnodeData(token='BTC', timeframe='24h', metric_names_file='metrics.txt')

# %%
gn.get_metrics()
# Out:
# Data saved as glassnode_BTC_market_price_usd_close_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_market_marketcap_usd_24h.csv in user_data/data/glassnode/24h
# Request error for addresses/sending_to_exchanges_count for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for addresses/sending_to_exchanges_count
# Request error for addresses/receiving_from_exchanges_count for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for addresses/receiving_from_exchanges_count
# Data saved as glassnode_BTC_addresses_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_addresses_sending_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_addresses_receiving_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_addresses_active_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_addresses_new_non_zero_count_24h.csv in user_data/data/glassnode/24h
# Request error for addresses/accumulation_count for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for addresses/accumulation_count
# Request error for addresses/accumulation_balance for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for addresses/accumulation_balance
# Data saved as glassnode_BTC_addresses_non_zero_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_addresses_min_point_zero_1_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_addresses_min_point_1_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_addresses_min_1_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_addresses_min_10_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_addresses_min_100_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_addresses_min_1k_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_addresses_min_10k_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_utxo_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_utxo_created_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_utxo_spent_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_utxo_created_value_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_utxo_spent_value_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_utxo_created_value_mean_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_utxo_spent_value_mean_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_utxo_created_value_median_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_utxo_spent_value_median_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_utxo_profit_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_utxo_loss_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_utxo_profit_relative_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_block_height_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_block_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_block_interval_mean_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_block_interval_median_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_block_size_mean_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_blockchain_block_size_sum_24h.csv in user_data/data/glassnode/24h
# Request error for defi/total_value_locked for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for defi/total_value_locked
# Data saved as glassnode_BTC_derivatives_futures_funding_rate_perpetual_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_open_interest_cash_margin_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_open_interest_crypto_margin_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_open_interest_crypto_margin_relative_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_estimated_leverage_ratio_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_options_atm_implied_volatility_1_week_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_options_atm_implied_volatility_1_month_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_options_atm_implied_volatility_3_months_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_options_atm_implied_volatility_6_months_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_options_atm_implied_volatility_all_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_volume_daily_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_volume_daily_perpetual_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_open_interest_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_open_interest_perpetual_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_liquidated_volume_short_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_liquidated_volume_short_mean_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_liquidated_volume_long_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_liquidated_volume_long_mean_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_liquidated_volume_long_relative_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_volume_daily_sum_all_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_volume_daily_perpetual_sum_all_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_open_interest_sum_all_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_open_interest_perpetual_sum_all_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_options_volume_daily_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_options_open_interest_sum_24h.csv in user_data/data/glassnode/24h
# Request error for derivatives/options_open_interest_distribution for BTC: b'unsupported exchange aggregated\n'
# Empty results returned for derivatives/options_open_interest_distribution
# Request error for derivatives/futures_term_structure for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for derivatives/futures_term_structure
# Request error for derivatives/futures_term_structure_by_exchange for BTC: b'unsupported exchange aggregated\n'
# Empty results returned for derivatives/futures_term_structure_by_exchange
# Data saved as glassnode_BTC_derivatives_futures_annualized_basis_3m_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_open_interest_latest_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_derivatives_futures_volume_daily_latest_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_distribution_balance_exchanges_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_distribution_exchange_net_position_change_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_distribution_balance_exchanges_relative_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_distribution_balance_exchanges_all_24h.csv in user_data/data/glassnode/24h
# Request error for distribution/balance_miners_all for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for distribution/balance_miners_all
# Request error for distribution/balance_miners_change for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for distribution/balance_miners_change
# Request error for distribution/balance_otc_desks for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for distribution/balance_otc_desks
# Data saved as glassnode_BTC_distribution_balance_1pct_holders_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_distribution_gini_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_distribution_herfindahl_24h.csv in user_data/data/glassnode/24h
# Error thrown for distribution/supply_contracts for BTC: <class 'Exception'>
# Empty results returned for distribution/supply_contracts
# Data saved as glassnode_BTC_eth2_staking_deposits_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_eth2_staking_volume_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_eth2_staking_validators_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_eth2_staking_total_deposits_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_eth2_staking_total_volume_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_eth2_staking_total_validators_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_eth2_staking_phase_0_goal_percent_24h.csv in user_data/data/glassnode/24h
# Error thrown for fees/gas_used_sum for BTC: <class 'Exception'>
# Empty results returned for fees/gas_used_sum
# Error thrown for fees/gas_used_mean for BTC: <class 'Exception'>
# Empty results returned for fees/gas_used_mean
# Error thrown for fees/gas_used_median for BTC: <class 'Exception'>
# Empty results returned for fees/gas_used_median
# Error thrown for fees/gas_limit_tx_mean for BTC: <class 'Exception'>
# Empty results returned for fees/gas_limit_tx_mean
# Error thrown for fees/gas_limit_tx_median for BTC: <class 'Exception'>
# Empty results returned for fees/gas_limit_tx_median
# Error thrown for fees/gas_price_mean for BTC: <class 'Exception'>
# Empty results returned for fees/gas_price_mean
# Error thrown for fees/gas_price_median for BTC: <class 'Exception'>
# Empty results returned for fees/gas_price_median
# Data saved as glassnode_BTC_fees_volume_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_fees_volume_mean_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_fees_volume_median_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_fees_fee_ratio_multiple_24h.csv in user_data/data/glassnode/24h
# Request error for fees/exchanges_relative for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for fees/exchanges_relative
# Request error for fees/exchanges_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for fees/exchanges_sum
# Request error for fees/exchanges_mean for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for fees/exchanges_mean
# Data saved as glassnode_BTC_indicators_rhodl_ratio_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_cvdd_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_balanced_price_usd_24h.csv in user_data/data/glassnode/24h
# Error thrown for indicators/difficulty_ribbon for BTC: <class 'Exception'>
# Empty results returned for indicators/difficulty_ribbon
# Data saved as glassnode_BTC_indicators_difficulty_ribbon_compression_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_nvt_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_nvts_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_velocity_24h.csv in user_data/data/glassnode/24h
# Request error for indicators/nvt_entity_adjusted for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/nvt_entity_adjusted
# Data saved as glassnode_BTC_indicators_cdd_supply_adjusted_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_cdd_supply_adjusted_binary_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_average_dormancy_supply_adjusted_24h.csv in user_data/data/glassnode/24h
# Request error for indicators/spent_output_price_distribution_ath for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/spent_output_price_distribution_ath
# Request error for indicators/spent_output_price_distribution_percent for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/spent_output_price_distribution_percent
# Data saved as glassnode_BTC_indicators_puell_multiple_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sopr_adjusted_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_reserve_risk_24h.csv in user_data/data/glassnode/24h
# Request error for indicators/sopr_less_155 for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/sopr_less_155
# Status 429. Pausing for 60 seconds...
# Request error for indicators/sopr_more_155 for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/sopr_more_155
# Request error for indicators/hodler_net_position_change for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/hodler_net_position_change
# Request error for indicators/hodled_lost_coins for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/hodled_lost_coins
# Data saved as glassnode_BTC_indicators_cyd_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_cyd_supply_adjusted_24h.csv in user_data/data/glassnode/24h
# Request error for indicators/cyd_account_based for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/cyd_account_based
# Request error for indicators/cyd_account_based_supply_adjusted for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/cyd_account_based_supply_adjusted
# Request error for indicators/cdd90_account_based_age_adjusted for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/cdd90_account_based_age_adjusted
# Data saved as glassnode_BTC_indicators_sopr_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_cdd_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_asol_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_msol_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_average_dormancy_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_liveliness_24h.csv in user_data/data/glassnode/24h
# Request error for indicators/sopr_account_based for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/sopr_account_based
# Request error for indicators/cdd_account_based for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/cdd_account_based
# Request error for indicators/asol_account_based for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/asol_account_based
# Request error for indicators/msol_account_based for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/msol_account_based
# Request error for indicators/dormancy_account_based for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/dormancy_account_based
# Data saved as glassnode_BTC_indicators_dormancy_flow_24h.csv in user_data/data/glassnode/24h
# Request error for indicators/liveliness_account_based for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/liveliness_account_based
# Request error for indicators/mvrv_account_based for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/mvrv_account_based
# Request error for indicators/rcap_account_based for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/rcap_account_based
# Data saved as glassnode_BTC_indicators_net_realized_profit_loss_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_realized_profit_loss_ratio_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_stock_to_flow_ratio_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_stock_to_flow_deflection_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_realized_profit_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_realized_loss_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_ssr_oscillator_24h.csv in user_data/data/glassnode/24h
# Request error for indicators/utxo_realized_price_distribution_ath for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/utxo_realized_price_distribution_ath
# Request error for indicators/utxo_realized_price_distribution_percent for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for indicators/utxo_realized_price_distribution_percent
# Data saved as glassnode_BTC_indicators_soab_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sol_1h_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sol_1h_24h_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sol_1d_1w_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sol_1w_1m_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sol_1m_3m_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sol_3m_6m_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sol_6m_12m_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sol_1y_2y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sol_2y_3y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sol_3y_5y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sol_5y_7y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sol_7y_10y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_sol_more_10y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svab_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svl_1h_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svl_1h_24h_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svl_1d_1w_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svl_1w_1m_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svl_1m_3m_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svl_3m_6m_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svl_6m_12m_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svl_1y_2y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svl_2y_3y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svl_3y_5y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svl_5y_7y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svl_7y_10y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_svl_more_10y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_bvin_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_investor_capitalization_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_realized_profits_to_value_ratio_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_indicators_pi_cycle_top_24h.csv in user_data/data/glassnode/24h
# Request error for institutions/grayscale_holdings_sum for BTC: b'404 page not found\n'
# Empty results returned for institutions/grayscale_holdings_sum
# Request error for institutions/grayscale_flows_sum for BTC: b'404 page not found\n'
# Empty results returned for institutions/grayscale_flows_sum
# Request error for institutions/grayscale_premium_percent for BTC: b'404 page not found\n'
# Empty results returned for institutions/grayscale_premium_percent
# Request error for institutions/grayscale_aum_sum for BTC: b'404 page not found\n'
# Empty results returned for institutions/grayscale_aum_sum
# Request error for institutions/grayscale_market_price_usd for BTC: b'404 page not found\n'
# Empty results returned for institutions/grayscale_market_price_usd
# Data saved as glassnode_BTC_institutions_purpose_etf_holdings_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_institutions_purpose_etf_flows_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_institutions_3iq_qbtc_holdings_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_institutions_3iq_qbtc_flows_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_institutions_3iq_qbtc_premium_percent_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_institutions_3iq_qbtc_outstanding_units_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_institutions_3iq_qbtc_aum_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_institutions_3iq_qbtc_market_price_usd_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_institutions_3iq_btcq_holdings_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_institutions_3iq_btcq_flows_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_institutions_3iq_btcq_premium_percent_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_institutions_3iq_btcq_outstanding_units_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_institutions_3iq_btcq_aum_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_institutions_3iq_btcq_market_price_usd_24h.csv in user_data/data/glassnode/24h
# Error thrown for institutions/3iq_qeth_holdings_sum for BTC: <class 'Exception'>
# Empty results returned for institutions/3iq_qeth_holdings_sum
# Error thrown for institutions/3iq_qeth_flows_sum for BTC: <class 'Exception'>
# Empty results returned for institutions/3iq_qeth_flows_sum
# Error thrown for institutions/3iq_qeth_premium_percent for BTC: <class 'Exception'>
# Empty results returned for institutions/3iq_qeth_premium_percent
# Error thrown for institutions/3iq_qeth_outstanding_units_sum for BTC: <class 'Exception'>
# Empty results returned for institutions/3iq_qeth_outstanding_units_sum
# Error thrown for institutions/3iq_qeth_aum_sum for BTC: <class 'Exception'>
# Empty results returned for institutions/3iq_qeth_aum_sum
# Error thrown for institutions/3iq_qeth_market_price_usd for BTC: <class 'Exception'>
# Empty results returned for institutions/3iq_qeth_market_price_usd
# Error thrown for institutions/3iq_ethq_holdings_sum for BTC: <class 'Exception'>
# Empty results returned for institutions/3iq_ethq_holdings_sum
# Error thrown for institutions/3iq_ethq_flows_sum for BTC: <class 'Exception'>
# Empty results returned for institutions/3iq_ethq_flows_sum
# Error thrown for institutions/3iq_ethq_premium_percent for BTC: <class 'Exception'>
# Empty results returned for institutions/3iq_ethq_premium_percent
# Error thrown for institutions/3iq_ethq_outstanding_units_sum for BTC: <class 'Exception'>
# Empty results returned for institutions/3iq_ethq_outstanding_units_sum
# Error thrown for institutions/3iq_ethq_aum_sum for BTC: <class 'Exception'>
# Empty results returned for institutions/3iq_ethq_aum_sum
# Error thrown for institutions/3iq_ethq_market_price_usd for BTC: <class 'Exception'>
# Empty results returned for institutions/3iq_ethq_market_price_usd
# Data saved as glassnode_BTC_lightning_channel_size_mean_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_lightning_channel_size_median_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_lightning_network_capacity_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_lightning_channels_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_lightning_nodes_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_market_deltacap_usd_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_market_marketcap_usd_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_market_mvrv_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_market_marketcap_realized_usd_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_market_mvrv_z_score_24h.csv in user_data/data/glassnode/24h
# Request error for market/mvrv_less_155 for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for market/mvrv_less_155
# Request error for market/mvrv_more_155 for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for market/mvrv_more_155
# Data saved as glassnode_BTC_market_price_realized_usd_24h.csv in user_data/data/glassnode/24h
# Error thrown for mining/difficulty_latest for BTC: <class 'Exception'>
# Empty results returned for mining/difficulty_latest
# Error thrown for mining/hash_rate_mean for BTC: <class 'Exception'>
# Empty results returned for mining/hash_rate_mean
# Data saved as glassnode_BTC_mining_revenue_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_mining_revenue_from_fees_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_mining_volume_mined_sum_24h.csv in user_data/data/glassnode/24h
# Request error for mining/miners_outflow_multiple for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for mining/miners_outflow_multiple
# Data saved as glassnode_BTC_mining_thermocap_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_mining_marketcap_thermocap_ratio_24h.csv in user_data/data/glassnode/24h
# Request error for mining/miners_unspent_supply for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for mining/miners_unspent_supply
# Request error for protocols/uniswap_transaction_count for BTC: b'asset not supported not supported asset BTC\n'
# Empty results returned for protocols/uniswap_transaction_count
# Request error for protocols/uniswap_liquidity_latest for BTC: b'asset not supported not supported asset BTC\n'
# Empty results returned for protocols/uniswap_liquidity_latest
# Status 429. Pausing for 60 seconds...
# Request error for protocols/uniswap_volume_sum for BTC: b'asset not supported not supported asset BTC\n'
# Empty results returned for protocols/uniswap_volume_sum
# Request error for supply/liquid_illiquid_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/liquid_illiquid_sum
# Request error for supply/liquid_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/liquid_sum
# Request error for supply/highly_liquid_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/highly_liquid_sum
# Request error for supply/illiquid_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/illiquid_sum
# Request error for supply/liquid_change for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/liquid_change
# Request error for supply/illiquid_change for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/illiquid_change
# Data saved as glassnode_BTC_supply_current_24h.csv in user_data/data/glassnode/24h
# Error thrown for supply/minted for BTC: <class 'Exception'>
# Empty results returned for supply/minted
# Error thrown for supply/burned for BTC: <class 'Exception'>
# Empty results returned for supply/burned
# Data saved as glassnode_BTC_supply_issued_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_inflation_rate_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_revived_more_1y_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_revived_more_2y_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_revived_more_3y_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_revived_more_5y_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_24h_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_1d_1w_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_1w_1m_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_1m_3m_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_3m_6m_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_6m_12m_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_1y_2y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_2y_3y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_3y_5y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_5y_7y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_7y_10y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_more_10y_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_hodl_waves_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_more_1y_percent_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_more_2y_percent_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_more_3y_percent_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_active_more_5y_percent_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_rcap_hodl_waves_24h.csv in user_data/data/glassnode/24h
# Request error for supply/sth_lth_realized_value_ratio for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/sth_lth_realized_value_ratio
# Data saved as glassnode_BTC_supply_current_adjusted_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_profit_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_loss_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_supply_profit_relative_24h.csv in user_data/data/glassnode/24h
# Request error for supply/sth_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/sth_sum
# Request error for supply/lth_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/lth_sum
# Request error for supply/sth_loss_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/sth_loss_sum
# Request error for supply/lth_loss_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/lth_loss_sum
# Request error for supply/sth_profit_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/sth_profit_sum
# Request error for supply/lth_profit_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/lth_profit_sum
# Request error for supply/lth_sth_profit_loss_relative for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/lth_sth_profit_loss_relative
# Request error for supply/lth_net_change for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/lth_net_change
# Request error for supply/sth_profit_loss_ratio for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for supply/sth_profit_loss_ratio
# Data saved as glassnode_BTC_transactions_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_rate_24h.csv in user_data/data/glassnode/24h
# Error thrown for transactions/contract_calls_external_count for BTC: <class 'Exception'>
# Empty results returned for transactions/contract_calls_external_count
# Error thrown for transactions/contract_calls_internal_count for BTC: <class 'Exception'>
# Empty results returned for transactions/contract_calls_internal_count
# Data saved as glassnode_BTC_transactions_size_mean_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_size_sum_24h.csv in user_data/data/glassnode/24h
# Request error for transactions/transfers_volume_by_size_entity_adjusted_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_by_size_entity_adjusted_sum
# Request error for transactions/transfers_volume_by_size_entity_adjusted_relative for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_by_size_entity_adjusted_relative
# Request error for transactions/transfers_to_otc_desks_count for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_to_otc_desks_count
# Request error for transactions/transfers_from_otc_desks_count for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_from_otc_desks_count
# Request error for transactions/transfers_volume_to_otc_desks_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_to_otc_desks_sum
# Request error for transactions/transfers_volume_from_otc_desks_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_from_otc_desks_sum
# Error thrown for transactions/transfers_count for BTC: <class 'Exception'>
# Empty results returned for transactions/transfers_count
# Error thrown for transactions/transfers_rate for BTC: <class 'Exception'>
# Empty results returned for transactions/transfers_rate
# Data saved as glassnode_BTC_transactions_transfers_volume_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_transfers_volume_mean_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_transfers_volume_median_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_transfers_volume_adjusted_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_transfers_volume_adjusted_mean_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_transfers_volume_adjusted_median_24h.csv in user_data/data/glassnode/24h
# Request error for transactions/transfers_volume_profit_relative for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_profit_relative
# Request error for transactions/transfers_volume_profit_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_profit_sum
# Request error for transactions/transfers_volume_loss_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_loss_sum
# Request error for transactions/entity_adjusted_count for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/entity_adjusted_count
# Request error for transactions/transfers_volume_entity_adjusted_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_entity_adjusted_sum
# Request error for transactions/transfers_volume_entity_adjusted_mean for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_entity_adjusted_mean
# Request error for transactions/transfers_volume_entity_adjusted_median for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_entity_adjusted_median
# Request error for transactions/transfers_from_miners_count for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_from_miners_count
# Request error for transactions/transfers_to_miners_count for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_to_miners_count
# Request error for transactions/transfers_volume_from_miners_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_from_miners_sum
# Request error for transactions/transfers_volume_to_miners_sum for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_to_miners_sum
# Request error for transactions/transfers_volume_miners_net for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_miners_net
# Data saved as glassnode_BTC_transactions_transfers_between_exchanges_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_transfers_volume_between_exchanges_sum_24h.csv in user_data/data/glassnode/24h
# Request error for transactions/transfers_volume_miners_to_exchanges for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_miners_to_exchanges
# Request error for transactions/transfers_volume_miners_to_exchanges_all for BTC: b'this asset is forbidden for endpoint\n'
# Empty results returned for transactions/transfers_volume_miners_to_exchanges_all
# Data saved as glassnode_BTC_transactions_transfers_volume_to_exchanges_mean_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_transfers_volume_from_exchanges_mean_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_transfers_volume_exchanges_net_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_transfers_to_exchanges_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_transfers_from_exchanges_count_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_transfers_volume_to_exchanges_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_transfers_volume_from_exchanges_sum_24h.csv in user_data/data/glassnode/24h
# Data saved as glassnode_BTC_transactions_transfers_volume_within_exchanges_sum_24h.csv in user_data/data/glassnode/24h
# Process complete...
