# %%
import pandas as pd
import requests
import json

# %load_ext autoreload
# %autoreload 2

import os
from pathlib import Path
os.chdir("/Users/mregan/Dev/litmus/")
print(Path.cwd())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/mregan/Dev/litmus

# %%
API_KEY = '22HCck9cUjuvUTrEvfc50rgcL7v'

# %%
metrics = ['market/mvrv_z_score']
token = 'BTC'

# %%
DIR = '/Users/mregan/Dev/litmus/user_data/litmus/glassnode/'

f = open(DIR + 'data/valid_requests.json', 'r')
valid_requests = json.load(f)
f.close()

# %%
btc_metrics = valid_requests['BTC']

# %%
for metric in btc_metrics:
    print(f"Trying to get {metric} for {token}")

    res = requests.get("https://api.glassnode.com/v1/metrics/{}".format(metric),
                       params={'a': token,
                               'i': '1h',
                               'api_key': API_KEY})
    
    if res.status_code == 200:  # If request was successful / Coin has this metric
        print(f"Successfully got {metric} metric for {token}")
        
    else:
        print(f"Status {res.status_code} Could not get {metric} metric for {token}")
# Out:
# Trying to get market/price_usd_close for BTC
# Successfully got market/price_usd_close metric for BTC
# Trying to get market/marketcap_usd for BTC
# Successfully got market/marketcap_usd metric for BTC
# Trying to get addresses/count for BTC
# Successfully got addresses/count metric for BTC
# Trying to get addresses/sending_count for BTC
# Successfully got addresses/sending_count metric for BTC
# Trying to get addresses/receiving_count for BTC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
#       1 for metric in btc_metrics:
#       2     print(f"Trying to get {metric} for {token}")
# ----> 4     res = requests.get("https://api.glassnode.com/v1/metrics/{}".format(metric),
#       5                        params={'a': token,
#       6                                'i': '1h',
#       7                                'api_key': API_KEY})
# ...

# %%
res = requests.get("https://api.glassnode.com/v1/metrics/{}".format('market/price_usd_close'),
                       params={'a': 'BTC',
                               'i': '1h',
                               'api_key': API_KEY})

# %%
df2 = pd.read_json(res.text, convert_dates=['t'])
df2
# Out:
#                          t             v
# 0      2010-07-17 23:00:00      0.049510
# 1      2010-07-18 00:00:00           NaN
# 2      2010-07-18 01:00:00           NaN
# 3      2010-07-18 02:00:00           NaN
# 4      2010-07-18 03:00:00      0.059410
# ...                    ...           ...
# 104100 2022-06-02 11:00:00  30154.046698
# 104101 2022-06-02 12:00:00  30090.176822
# 104102 2022-06-02 13:00:00  29845.120028
# 104103 2022-06-02 14:00:00  29983.006253
# 104104 2022-06-02 15:00:00  30086.257461
#
# [104105 rows x 2 columns]

# %%
df = pd.read_json(res.text, convert_dates=['t'])

df.rename({'v': metrics[0].replace('/', '_'),
           't': 'date'}, axis='columns', inplace=True)

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 df = pd.read_json(res.text, convert_dates=['t'])
#       3 df.rename({'v': metrics[0].replace('/', '_'),
#       4            't': 'date'}, axis='columns', inplace=True)
#       6 df
#
# File ~/Dev/litmus/.env/lib/python3.9/site-packages/pandas/util/_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~/Dev/litmus/.env/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
# ...

# %%
from user_data.litmus.glassnode import download_data

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
glass = download_data.GlassnodeData()

# %%
a = glass.get_metric('BTC', 'market/price_usd_close', '24h')
b = glass.get_metric('BTC', 'market/marketcap_usd', '24h')
# Out:
# Successfully got market/price_usd_close metric for BTC
# Successfully got market/marketcap_usd metric for BTC

# %%
pd.concat([a,b], axis=1)
# Out:
#                            market_price_usd_close  market_marketcap_usd
# date
# 2010-07-17 00:00:00+00:00                0.049510          1.702649e+05
# 2010-07-18 00:00:00+00:00                0.085840          2.959420e+05
# 2010-07-19 00:00:00+00:00                0.080800          2.792690e+05
# 2010-07-20 00:00:00+00:00                0.074733          2.589772e+05
# 2010-07-21 00:00:00+00:00                0.079210          2.753102e+05
# ...                                           ...                   ...
# 2022-05-29 00:00:00+00:00            29424.727879          5.606312e+11
# 2022-05-30 00:00:00+00:00            31703.036055          6.040704e+11
# 2022-05-31 00:00:00+00:00            31835.105083          6.066159e+11
# 2022-06-01 00:00:00+00:00            29791.517810          5.677008e+11
# 2022-06-02 00:00:00+00:00            30471.300002                   NaN
#
# [4339 rows x 2 columns]

# %%
metrics = glass.get_metric_names('metrics.txt')[:5]
glass.get_metrics('BTC', metrics, '24h', save=True)
# Out:
# Successfully got market/price_usd_close metric for BTC
# Successfully got market/marketcap_usd metric for BTC
# Status 403 Could not get addresses/sending_to_exchanges_count metric for BTC
# Status 403 Could not get addresses/receiving_from_exchanges_count metric for BTC
# Successfully got addresses/count metric for BTC
# Data saved as glassnode_BTC_24h.csv in user_data/data/glassnode/
#                            market_price_usd_close  market_marketcap_usd  \
# date
# 2009-01-03 00:00:00+00:00                     NaN                   NaN
# 2009-01-04 00:00:00+00:00                     NaN                   NaN
# 2009-01-05 00:00:00+00:00                     NaN                   NaN
# 2009-01-06 00:00:00+00:00                     NaN                   NaN
# 2009-01-07 00:00:00+00:00                     NaN                   NaN
# ...                                           ...                   ...
# 2022-05-29 00:00:00+00:00            29424.727879          5.606312e+11
# ...

# %%
# Out:
# ['market/price_usd_close',
#  'market/marketcap_usd',
#  'addresses/sending_to_exchanges_count',
#  'addresses/receiving_from_exchanges_count',
#  'addresses/count',
#  'addresses/sending_count',
#  'addresses/receiving_count',
#  'addresses/active_count',
#  'addresses/new_non_zero_count',
#  'addresses/accumulation_count',
#  'addresses/accumulation_balance',
#  'addresses/non_zero_count',
#  'addresses/min_point_zero_1_count',
#  'addresses/min_point_1_count',
#  'addresses/min_1_count',
#  'addresses/min_10_count',
#  'addresses/min_100_count',
#  'addresses/min_1k_count',
#  'addresses/min_10k_count',
#  'blockchain/utxo_count',
#  'blockchain/utxo_created_count',
#  'blockchain/utxo_spent_count',
#  'blockchain/utxo_created_value_sum',
#  'blockchain/utxo_spent_value_sum',
#  'blockchain/utxo_created_value_mean',
#  'blockchain/utxo_spent_value_mean',
#  'blockchain/utxo_created_value_median',
#  'blockchain/utxo_spent_value_median',
#  'blockchain/utxo_profit_count',
# ...
