# %%
import pandas as pd
import numpy as np

# %%
dataframe = pd.DataFrame(np.random.random(100), columns=["rand"])
dataframe
# Out:
#         rand
# 0   0.699317
# 1   0.498452
# 2   0.009150
# 3   0.188141
# 4   0.660382
# ..       ...
# 95  0.409769
# 96  0.757937
# 97  0.140149
# 98  0.191506
# 99  0.236097
#
# [100 rows x 1 columns]

# %%
(1 - dataframe["rand"].shift(-1) / dataframe["rand"]).plot()
dataframe["rand"].plot(secondary_y=True)
# Out:
# <AxesSubplot: >

# %%
dataframe["pct_c"] = dataframe["rand"].pct_change(2).shift(-2)
dataframe
# Out:
#         rand      pct_c
# 0   0.699317  -0.986916
# 1   0.498452  -0.622551
# 2   0.009150  71.174947
# 3   0.188141   0.427913
# 4   0.660382  -0.368286
# ..       ...        ...
# 95  0.409769  -0.657980
# 96  0.757937  -0.747333
# 97  0.140149   0.684614
# 98  0.191506        NaN
# 99  0.236097        NaN
#
# [100 rows x 2 columns]

# %%
dataframe.loc[:, "rand"]
# Out:
#   Cell In[31], line 1
#     dataframe.loc[[:, "rand"]]
#                    ^
# SyntaxError: invalid syntax
