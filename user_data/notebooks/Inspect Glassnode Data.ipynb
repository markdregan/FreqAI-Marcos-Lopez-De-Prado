# %%
import pandas as pd
import numpy as np

from user_data.litmus import indicator_helpers
from user_data.litmus import external_informative_data as eid

# %load_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path
os.chdir("/Users/mregan/Dev/litmus/")
print(Path.cwd())

pd.options.display.max_columns = 400
pd.options.display.max_rows = 400
# Out:
# /Users/mregan/Dev/litmus

# %%
glassnode_df = eid.load_local_data('glassnode_BTC_1d.csv', 'glassnode')
glassnode_df.tail()
# Out:
#                            Unnamed: 0  market_price_usd_close  \
# date
# 2022-05-28 00:00:00+00:00        4333            29030.561174
# 2022-05-29 00:00:00+00:00        4334            29424.727879
# 2022-05-30 00:00:00+00:00        4335            31703.036055
# 2022-05-31 00:00:00+00:00        4336            31835.105083
# 2022-06-01 00:00:00+00:00        4337            31587.585433
#
#                            market_marketcap_usd_x  addresses_count  \
# date
# 2022-05-28 00:00:00+00:00            5.530941e+11      982886800.0
# 2022-05-29 00:00:00+00:00            5.606312e+11      983209361.0
# 2022-05-30 00:00:00+00:00            6.040704e+11      983598121.0
# 2022-05-31 00:00:00+00:00            6.066159e+11      984006014.0
# 2022-06-01 00:00:00+00:00                     NaN              NaN
#
#                            addresses_sending_count  addresses_receiving_count  \
# date
# 2022-05-28 00:00:00+00:00                 494943.0                   576380.0
# ...

# %%
indicator_helpers.log_delta(glassnode_df, lag=1)
# Out:
#                            Unnamed: 0  market_price_usd_close  \
# date
# 2010-07-17 00:00:00+00:00           0            2.451240e-03
# 2010-07-18 00:00:00+00:00           1            7.368506e-03
# 2010-07-19 00:00:00+00:00           4            6.528640e-03
# 2010-07-20 00:00:00+00:00           9            5.585071e-03
# 2010-07-21 00:00:00+00:00          16            6.274224e-03
# ...                               ...                     ...
# 2022-05-28 00:00:00+00:00    18774889            8.427735e+08
# 2022-05-29 00:00:00+00:00    18783556            8.658146e+08
# 2022-05-30 00:00:00+00:00    18792225            1.005082e+09
# 2022-05-31 00:00:00+00:00    18800896            1.013474e+09
# 2022-06-01 00:00:00+00:00    18809569            9.977756e+08
#
#                            market_marketcap_usd_x  addresses_count  \
# date
# 2010-07-17 00:00:00+00:00            2.899013e+10     7.565346e+09
# 2010-07-18 00:00:00+00:00            8.758166e+10     7.646803e+09
# ...

# %%
glassnode_df.plot(subplots=True, figsize=(13,400))
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
# ...
